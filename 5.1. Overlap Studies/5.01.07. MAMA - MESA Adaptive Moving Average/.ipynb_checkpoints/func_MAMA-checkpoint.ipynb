# %% [markdown]
# #### Carregamento de dados

# %%
# %run bot_libraries.ipynb

# %% [raw]
# %run data_download.ipynb

# %%
data = pd.read_csv("CryptoBot_202103006Mv001.csv")

# %%
# %run tratamento_de_dados.ipynb

# %% [markdown]
# #### Gráfico 'Open', 'High', 'Low', 'Close'

# %%
from matplotlib.pyplot import legend
from matplotlib import pylab
data_0 = data[['Open', 'High', 'Low', 'Close']]
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, data_0)
plt.legend(line, data_0.columns)

# %% [markdown]
# ##### 5.1.7. MAMA - MESA Adaptive Moving Average
# NOTE: The MAMA function has an unstable period.

# %%
mama, fama = talib.MAMA(close, fastlimit=0.5, slowlimit=0.05)

# %%
data_metric = pd.DataFrame({"MAMA": mama, "FAMA": fama})

data_0 = data_metric[["MAMA", "FAMA"]]
plt.figure(figsize=(12,5), dpi=100)



#Preço
data_p = pd.DataFrame()
data_p['Close'] = data['Close']
line_p = plt.plot(data_p.index, data_p)
# plt.legend(line_p, data_p.columns)


line = plt.plot(data_0.index, data_0)
plt.legend((*line_p, *line), (*data_p.columns, *data_0.columns))
plt.show()

# %% [markdown]
# #### Dataframe

# %%
data_metric = pd.DataFrame()
for i in range(len(data)):
    data_metric = data_metric.append({"Close": data['Close'][i], "MAMA": mama[i], "FAMA": fama[i]}, ignore_index = True)

# %%
data_metric_drop = data_metric.dropna().reset_index(drop = True)
data_metric_drop
# Out:
#                 Close              FAMA              MAMA
# 0   337754.0000000000 328377.4010410803 337827.8337264211
# 1   337955.0000000000 328613.8208160558 337834.1920401001
# 2   337958.0000000000 328844.4848566068 337840.3824380951
# 3   338127.0000000000 331129.2864472170 337983.6912190475
# 4   338125.0000000000 331300.8232024889 337990.7566580951
# ..                ...               ...               ...
# 463 331555.0000000000 331833.2993433992 331602.2660247092
# 464 331740.0000000000 331827.6956779010 331609.1527234737
# 465 331181.0000000000 331821.6969131360 331587.7450873000
# 466 331732.0000000000 331816.0284361310 331594.9578329350
# 467 331728.0000000000 331777.3910562151 331661.4789164675
#
# [468 rows x 3 columns]

# %% [markdown]
# #### Loop de descisão de compra com a métrica escolhida
