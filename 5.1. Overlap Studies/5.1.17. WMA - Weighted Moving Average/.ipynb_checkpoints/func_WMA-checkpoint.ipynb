# %% [markdown]
# #### Carregamento de dados

# %%
# %run bot_libraries.ipynb

# %% [raw]
# %run data_download.ipynb

# %%
data = pd.read_csv("CryptoBot_202103006Mv001.csv")

# %%
# %run tratamento_de_dados.ipynb

# %% [markdown]
# #### Gráfico 'Open', 'High', 'Low', 'Close'

# %%
from matplotlib.pyplot import legend
from matplotlib import pylab
data_0 = data[['Open', 'High', 'Low', 'Close']]
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, data_0)
plt.legend(line, data_0.columns)

# %% [markdown]
# ##### 5.1.17. WMA - Weighted Moving Average

# %%
real = talib.WMA(close, timeperiod=30)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %%
data_metric = pd.DataFrame({"WMA": real})

data_0 = data_metric[["WMA"]]
plt.figure(figsize=(12,5), dpi=100)



#Preço
data_p = pd.DataFrame()
data_p['Close'] = data['Close']
line_p = plt.plot(data_p.index, data_p)
# plt.legend(line_p, data_p.columns)


line = plt.plot(data_0.index, data_0)
plt.legend((*line_p, *line), (*data_p.columns, *data_0.columns))
plt.show()

# %% [markdown]
# #### Dataframe

# %%
data_metric = pd.DataFrame()
for i in range(len(data)):
    data_metric = data_metric.append({"Close": data['Close'][i], "WMA": real[i]}, ignore_index = True)

# %%
data_metric_drop = data_metric.dropna().reset_index(drop = True)
data_metric_drop
# Out:
#                 Close               WMA
# 0   338130.0000000000 338835.0838709677
# 1   338128.0000000000 338775.2881720430
# 2   337755.0000000000 338693.3032258064
# 3   337754.0000000000 338615.1053763441
# 4   337955.0000000000 338553.7290322580
# ..                ...               ...
# 466 331555.0000000000 331929.2881720430
# 467 331740.0000000000 331907.7720430107
# 468 331181.0000000000 331851.2086021506
# 469 331732.0000000000 331833.3397849462
# 470 331728.0000000000 331816.8516129032
#
# [471 rows x 2 columns]

# %% [markdown]
# #### Loop de descisão de compra com a métrica escolhida
