# %% [markdown]
# #### Carregamento de dados

# %%
# %run bot_libraries.ipynb

# %% [raw]
# %run data_download.ipynb

# %%
data = pd.read_csv("CryptoBot_202103006Mv001.csv")

# %%
# %run tratamento_de_dados.ipynb

# %% [markdown]
# #### Gráfico 'Open', 'High', 'Low', 'Close'

# %%
from matplotlib.pyplot import legend
from matplotlib import pylab
data_0 = data[['Open', 'High', 'Low', 'Close']]
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, data_0)
plt.legend(line, data_0.columns)

# %% [markdown]
# ##### 5.1.15. TEMA - Triple Exponential Moving Average

# %%
real = talib.TEMA(close, timeperiod=30)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %%
data_metric = pd.DataFrame({"TEMA": real})

data_0 = data_metric[["TEMA"]]
plt.figure(figsize=(12,5), dpi=100)



#Preço
data_p = pd.DataFrame()
data_p['Close'] = data['Close']
line_p = plt.plot(data_p.index, data_p)
# plt.legend(line_p, data_p.columns)


line = plt.plot(data_0.index, data_0)
plt.legend((*line_p, *line), (*data_p.columns, *data_0.columns))
plt.show()

# %% [markdown]
# #### Dataframe

# %%
data_metric = pd.DataFrame()
for i in range(len(data)):
    data_metric = data_metric.append({"Close": data['Close'][i], "TEMA": real[i]}, ignore_index = True)

# %%
data_metric_drop = data_metric.dropna().reset_index(drop = True)
data_metric_drop
# Out:
#                 Close              TEMA
# 0   338509.0000000000 338206.1847601557
# 1   338497.0000000000 338263.8241889488
# 2   338162.0000000000 338253.4350436081
# 3   338159.0000000000 338243.6508514699
# 4   338499.0000000000 338296.6164216505
# ..                ...               ...
# 408 331555.0000000000 331545.9803239019
# 409 331740.0000000000 331541.4944055596
# 410 331181.0000000000 331438.0572445848
# 411 331732.0000000000 331449.3749194594
# 412 331728.0000000000 331460.5258862650
#
# [413 rows x 2 columns]

# %% [markdown]
# #### Loop de descisão de compra com a métrica escolhida
