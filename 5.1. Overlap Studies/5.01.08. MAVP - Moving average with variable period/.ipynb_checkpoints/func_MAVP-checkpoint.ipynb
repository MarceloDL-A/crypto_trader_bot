# %% [markdown]
# #### Carregamento de dados

# %%
# %run bot_libraries.ipynb

# %% [raw]
# %run data_download.ipynb

# %%
data = pd.read_csv("CryptoBot_202103006Mv001.csv")

# %%
# %run tratamento_de_dados.ipynb

# %% [markdown]
# #### Gráfico 'Open', 'High', 'Low', 'Close'

# %%
from matplotlib.pyplot import legend
from matplotlib import pylab
data_0 = data[['Open', 'High', 'Low', 'Close']]
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, data_0)
plt.legend(line, data_0.columns)

# %% [markdown]
# ##### 5.1.8. MAVP - Moving average with variable period

# %% [markdown]
# ###### ***np.array(data['Close'] é apenas um exempo para o parametro periods. É preciso analisar melhor esse parâmetro.

# %%
real = talib.MAVP(close, periods=np.array(data['Close']), minperiod=2, maxperiod=30, matype=0)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %%
data_metric = pd.DataFrame({"MAVP": real})

data_0 = data_metric[["MAVP"]]
plt.figure(figsize=(12,5), dpi=100)



#Preço
data_p = pd.DataFrame()
data_p['Close'] = data['Close']
line_p = plt.plot(data_p.index, data_p)
# plt.legend(line_p, data_p.columns)


line = plt.plot(data_0.index, data_0)
plt.legend((*line_p, *line), (*data_p.columns, *data_0.columns))
plt.show()

# %% [markdown]
# #### Dataframe

# %%
data_metric = pd.DataFrame()
for i in range(len(data)):
    data_metric = data_metric.append({"Close": data['Close'][i], "MAVP": real[i]}, ignore_index = True)

# %%
data_metric_drop = data_metric.dropna().reset_index(drop = True)
data_metric_drop
# Out:
#                 Close              MAVP
# 0   338130.0000000000 339054.8333333333
# 1   338128.0000000000 339025.7666666667
# 2   337755.0000000000 338966.0666666667
# 3   337754.0000000000 338906.3333333333
# 4   337955.0000000000 338853.3000000000
# ..                ...               ...
# 466 331555.0000000000 332073.5000000000
# 467 331740.0000000000 332057.7333333333
# 468 331181.0000000000 332008.9666666667
# 469 331732.0000000000 331983.5666666667
# 470 331728.0000000000 331959.9666666667
#
# [471 rows x 2 columns]

# %% [markdown]
# #### Loop de descisão de compra com a métrica escolhida
