# %% [markdown]
# #### Carregamento de dados

# %%
# %run bot_libraries.ipynb

# %% [raw]
# %run data_download.ipynb

# %%
data = pd.read_csv("CryptoBot_202103006Mv001.csv")

# %%
# %run tratamento_de_dados.ipynb

# %% [markdown]
# #### Gráfico 'Open', 'High', 'Low', 'Close'

# %%
from matplotlib.pyplot import legend
from matplotlib import pylab
data_0 = data[['Open', 'High', 'Low', 'Close']]
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, data_0)
plt.legend(line, data_0.columns)

# %% [markdown]
# ##### 5.1.9. MIDPOINT - MidPoint over period

# %%
real = talib.MIDPOINT(close, timeperiod=14)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %%
data_metric = pd.DataFrame({"MIDPOINT": real})

data_0 = data_metric[["MIDPOINT"]]
plt.figure(figsize=(12,5), dpi=100)



#Preço
data_p = pd.DataFrame()
data_p['Close'] = data['Close']
line_p = plt.plot(data_p.index, data_p)
# plt.legend(line_p, data_p.columns)


line = plt.plot(data_0.index, data_0)
plt.legend((*line_p, *line), (*data_p.columns, *data_0.columns))
plt.show()

# %% [markdown]
# #### Dataframe

# %%
data_metric = pd.DataFrame()
for i in range(len(data)):
    data_metric = data_metric.append({"Close": data['Close'][i], "MIDPOINT": real[i]}, ignore_index = True)

# %%
data_metric_drop = data_metric.dropna().reset_index(drop = True)
data_metric_drop
# Out:
#                 Close          MIDPOINT
# 0   339380.0000000000 339283.0000000000
# 1   339384.0000000000 339283.0000000000
# 2   339150.0000000000 339283.0000000000
# 3   339347.0000000000 339283.0000000000
# 4   339347.0000000000 339283.0000000000
# ..                ...               ...
# 482 331555.0000000000 331801.0000000000
# 483 331740.0000000000 331801.0000000000
# 484 331181.0000000000 331603.0000000000
# 485 331732.0000000000 331603.0000000000
# 486 331728.0000000000 331603.0000000000
#
# [487 rows x 2 columns]

# %% [markdown]
# #### Loop de descisão de compra com a métrica escolhida
