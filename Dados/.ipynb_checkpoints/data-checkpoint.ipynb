# %%
import pandas as pd

# %%
df = pd.read_csv("Binance_BTCUSDT_minute.csv")
# Out:
# C:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,3,4,5,6,7,8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#                                                                                                                                     https://www.CryptoDataDownload.com
# unix          date                symbol   open           high           low            close          Volume BTC  Volume USDT                              tradecount
# 1618706100000 2021-04-18 00:35:00 BTC/USDT 59739.01000000 59773.95000000 59712.12000000 59773.90000000 29.95507200 1789739.98406046                               1179
# 1618706040000 2021-04-18 00:34:00 BTC/USDT 59592.47000000 59739.01000000 59561.00000000 59739.01000000 73.66219900 4393520.97791883                               2262
# 1618705980000 2021-04-18 00:33:00 BTC/USDT 59634.42000000 59650.33000000 59550.00000000 59592.47000000 90.32657900 5384038.59820220                               2654
# ...

# %%
df.describe()
# Out:
#         https://www.CryptoDataDownload.com
# count                               313638
# unique                               10982
# top                                    359
# freq                                   242

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 313638 entries, ('unix', 'date', 'symbol', 'open', 'high', 'low', 'close', 'Volume BTC', 'Volume USDT') to (1599856800000, '2020-09-11 20:40:00', 'BTC/USDT', 10317.0, 10317.01, 10314.36, 10316.0, 32.997684, 340398.47755266)
# Data columns (total 1 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   https://www.CryptoDataDownload.com  313638 non-null  object
# dtypes: object(1)
# memory usage: 110.1+ MB
